# %%
import pandas as pd
perf = pd.read_pickle('../signal_algo-2015.pickle') # read in perf DataFrame
perf.tail()
# Out:
#                            Equity(0 [AAPL])  Equity(33 [AMZN])  \
# 2015-12-24 18:00:00+00:00               0.0                0.0
# 2015-12-28 21:00:00+00:00               0.0                0.0
# 2015-12-29 21:00:00+00:00               0.0                0.0
# 2015-12-30 21:00:00+00:00               0.0                0.0
# 2015-12-31 21:00:00+00:00               0.0                0.0
#
#                            algo_volatility  algorithm_period_return  \
# 2015-12-24 18:00:00+00:00       715.908859                 9.144418
# 2015-12-28 21:00:00+00:00       714.470814                 8.098945
# 2015-12-29 21:00:00+00:00       713.040463                 9.189959
# 2015-12-30 21:00:00+00:00       711.618390                11.128003
# 2015-12-31 21:00:00+00:00       710.205745                10.587247
#
#                                 alpha  benchmark_period_return  \
# 2015-12-24 18:00:00+00:00  746.285134                 0.000681
# ...

# %%
# %pylab inline
figsize(12, 12)
import matplotlib.pyplot as plt

ax1 = plt.subplot(211)
# perf['algorithm_period_return'].plot(ax=ax1)
perf['benchmark_period_return'].plot(ax=ax1)
ax1.set_ylabel('returns')
# Out:
# Populating the interactive namespace from numpy and matplotlib
